# %%
vals = [True, False]



print (f"{'A':<2}{'B':<4} {'A&B':<2}")
for a in vals:
  for b in vals:
    print (f"{a :<2}{b :<2}-> {a and b:<2}")
# Out:
# A B    A&B
# 1 1 -> 1
# 1 0 -> 0
# 0 1 -> 0
# 0 0 -> 0
